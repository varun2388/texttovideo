# %% [markdown]
# <a href="https://colab.research.google.com/github/varun2388/texttovideo/blob/main/Untitled151.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = 5
num2 = 10

sum_of_numbers = num1 + num2

print(f"The sum of {num1} and {num2} is: {sum_of_numbers}")
# Out:
# The sum of 5 and 10 is: 15
